# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#read data

df=pd.read_csv(r'C:/Users/HP/Downloads/fifa21.csv')

# Set display options to show all columns
pd.set_option('display.max_columns', None)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11900\3304760895.py:3: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r'C:/Users/HP/Downloads/fifa21.csv')

# %%
df.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# 2  http://sofifa.com/player/200389/jan-oblak/210006/    Slovenia   27    91
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium   29    91
# 4  http://sofifa.com/player/190871/neymar-da-silv...      Brazil   28    91
#
#    POT                         Club     Contract   Positions Height Weight  \
# 0   93         \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg
# 1   92             \n\n\n\nJuventus  2018 ~ 2022      ST, LW  187cm   83kg
# 2   93      \n\n\n\nAtlético Madrid  2014 ~ 2023          GK  188cm   87kg
# 3   91      \n\n\n\nManchester City  2015 ~ 2023     CAM, CM  181cm   70kg
# 4   91  \n\n\n\nParis Saint-Germain  2017 ~ 2022     LW, CAM  175cm   68kg
#
#   Preferred Foot  BOV Best Position        Joined Loan Date End    Value  \
# 0           Left   93            RW   Jul 1, 2004           NaN  €103.5M
# 1          Right   92            ST  Jul 10, 2018           NaN     €63M
# 2          Right   91            GK  Jul 16, 2014           NaN    €120M
# 3          Right   91           CAM  Aug 30, 2015           NaN    €129M
# 4          Right   91            LW   Aug 3, 2017           NaN    €132M
#
#     Wage Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# 0  €560K        €138.4M        429        85         95                70
# 1  €220K         €75.9M        437        84         95                90
# 2  €125K        €159.4M         95        13         11                15
# 3  €370K          €161M        407        94         82                55
# 4  €270K        €166.5M        408        85         87                62
#
#    Short Passing  Volleys  Skill  Dribbling  Curve  FK Accuracy  Long Passing  \
# 0             91       88    470         96     93           94            91
# 1             82       86    414         88     81           76            77
# 2             43       13    109         12     13           14            40
# 3             94       82    441         88     85           83            93
# 4             87       87    448         95     88           89            81
#
#    Ball Control  Movement  Acceleration  Sprint Speed  Agility  Reactions  \
# 0            96       451            91            80       91         94
# 1            92       431            87            91       87         95
# 2            30       307            43            60       67         88
# 3            92       398            77            76       78         91
# 4            95       453            94            89       96         91
#
#    Balance  Power  Shot Power  Jumping  Stamina  Strength  Long Shots  \
# 0       95    389          86       68       72        69          94
# 1       71    444          94       95       84        78          93
# 2       49    268          59       78       41        78          12
# 3       76    408          91       63       89        74          91
# 4       83    357          80       62       81        50          84
#
#    Mentality  Aggression  Interceptions  Positioning  Vision  Penalties  \
# 0        347          44             40           93      95         75
# 1        353          63             29           95      82         84
# 2        140          34             19           11      65         11
# 3        408          76             66           88      94         84
# 4        356          51             36           87      90         92
#
#    Composure  Defending  Marking  Standing Tackle  Sliding Tackle  \
# 0         96         91       32               35              24
# 1         95         84       28               32              24
# 2         68         57       27               12              18
# 3         91        186       68               65              53
# 4         93         94       35               30              29
#
#    Goalkeeping  GK Diving  GK Handling  GK Kicking  GK Positioning  \
# 0           54          6           11          15              14
# 1           58          7           11          15              14
# 2          437         87           92          78              90
# 3           56         15           13           5              10
# 4           59          9            9          15              15
#
#    GK Reflexes  Total Stats  Base Stats  W/F  SM     A/W     D/W   IR  PAC  \
# 0            8         2231         466  4 ★  4★  Medium     Low  5 ★   85
# 1           11         2221         464  4 ★  5★    High     Low  5 ★   89
# 2           90         1413         489  3 ★  1★  Medium  Medium  3 ★   87
# 3           13         2304         485  5 ★  4★    High    High  4 ★   76
# 4           11         2175         451  5 ★  5★    High  Medium  5 ★   91
#
#    SHO  PAS  DRI  DEF  PHY Hits
# 0   92   91   95   38   65  771
# 1   93   81   89   35   77  562
# 2   92   78   90   52   90  150
# 3   86   93   88   64   78  207
# 4   85   86   94   36   59  595

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'LongName', 'photoUrl', 'playerUrl', 'Nationality', 'Age',
#        '↓OVA', 'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS',
#        'DRI', 'DEF', 'PHY', 'Hits'],
#       dtype='object')

# %%
df=df.drop(columns=['photoUrl','playerUrl','Loan Date End'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 74 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   LongName          18979 non-null  object
#  3   Nationality       18979 non-null  object
#  4   Age               18979 non-null  int64
#  5   ↓OVA              18979 non-null  int64
#  6   POT               18979 non-null  int64
#  7   Club              18979 non-null  object
#  8   Contract          18979 non-null  object
#  9   Positions         18979 non-null  object
#  10  Height            18979 non-null  object
#  11  Weight            18979 non-null  object
#  12  Preferred Foot    18979 non-null  object
#  13  BOV               18979 non-null  int64
#  14  Best Position     18979 non-null  object
#  15  Joined            18979 non-null  object
#  16  Value             18979 non-null  object
#  17  Wage              18979 non-null  object
#  18  Release Clause    18979 non-null  object
#  19  Attacking         18979 non-null  int64
#  20  Crossing          18979 non-null  int64
#  21  Finishing         18979 non-null  int64
#  22  Heading Accuracy  18979 non-null  int64
#  23  Short Passing     18979 non-null  int64
#  24  Volleys           18979 non-null  int64
#  25  Skill             18979 non-null  int64
#  26  Dribbling         18979 non-null  int64
#  27  Curve             18979 non-null  int64
#  28  FK Accuracy       18979 non-null  int64
#  29  Long Passing      18979 non-null  int64
#  30  Ball Control      18979 non-null  int64
#  31  Movement          18979 non-null  int64
#  32  Acceleration      18979 non-null  int64
#  33  Sprint Speed      18979 non-null  int64
#  34  Agility           18979 non-null  int64
#  35  Reactions         18979 non-null  int64
#  36  Balance           18979 non-null  int64
#  37  Power             18979 non-null  int64
#  38  Shot Power        18979 non-null  int64
#  39  Jumping           18979 non-null  int64
#  40  Stamina           18979 non-null  int64
#  41  Strength          18979 non-null  int64
#  42  Long Shots        18979 non-null  int64
#  43  Mentality         18979 non-null  int64
#  44  Aggression        18979 non-null  int64
#  45  Interceptions     18979 non-null  int64
#  46  Positioning       18979 non-null  int64
#  47  Vision            18979 non-null  int64
#  48  Penalties         18979 non-null  int64
#  49  Composure         18979 non-null  int64
#  50  Defending         18979 non-null  int64
#  51  Marking           18979 non-null  int64
#  52  Standing Tackle   18979 non-null  int64
#  53  Sliding Tackle    18979 non-null  int64
#  54  Goalkeeping       18979 non-null  int64
#  55  GK Diving         18979 non-null  int64
#  56  GK Handling       18979 non-null  int64
#  57  GK Kicking        18979 non-null  int64
#  58  GK Positioning    18979 non-null  int64
#  59  GK Reflexes       18979 non-null  int64
#  60  Total Stats       18979 non-null  int64
#  61  Base Stats        18979 non-null  int64
#  62  W/F               18979 non-null  object
#  63  SM                18979 non-null  object
#  64  A/W               18979 non-null  object
#  65  D/W               18979 non-null  object
#  66  IR                18979 non-null  object
#  67  PAC               18979 non-null  int64
#  68  SHO               18979 non-null  int64
#  69  PAS               18979 non-null  int64
#  70  DRI               18979 non-null  int64
#  71  DEF               18979 non-null  int64
#  72  PHY               18979 non-null  int64
#  73  Hits              16384 non-null  object
# dtypes: int64(54), object(20)
# memory usage: 10.7+ MB

# %% [markdown]
# Columns to clean:
# 1. Convert values in Height column to 1 scale(cm)
# 2. Convert values in Weight column to 1 scale(kgs)
# 3. Remove new line character in Club column
# 4. Create Day, Month Year columns based on Joined column
# 5. Clean Value, Wage and Release_Clause columns
# 6. Some columns have 'star' characters. Strip those columns of these stars and make the columns numerical

# %%
df['Club']
# Out:
# 0               \n\n\n\nFC Barcelona
# 1                   \n\n\n\nJuventus
# 2            \n\n\n\nAtlético Madrid
# 3            \n\n\n\nManchester City
# 4        \n\n\n\nParis Saint-Germain
#                     ...
# 18974             \n\n\n\nWuhan Zall
# 18975        \n\n\n\nOldham Athletic
# 18976             \n\n\n\nDerry City
# 18977       \n\n\n\nDalian YiFang FC
# 18978       \n\n\n\nDalian YiFang FC
# Name: Club, Length: 18979, dtype: object

# %%
converted_club=[]

for clubs in df['Club']:
    clubs=clubs.replace("\n",'')
    converted_club.append(clubs)
df['Club']=converted_club
df['Club']
# Out:
# 0               FC Barcelona
# 1                   Juventus
# 2            Atlético Madrid
# 3            Manchester City
# 4        Paris Saint-Germain
#                 ...
# 18974             Wuhan Zall
# 18975        Oldham Athletic
# 18976             Derry City
# 18977       Dalian YiFang FC
# 18978       Dalian YiFang FC
# Name: Club, Length: 18979, dtype: object

# %%
converted_heights=[]

for height in df['Height']:
    if "'" in height or '"' in height:
        feet, inches=height.split("'")
        inches=inches.strip('"')
        total_inches=int(feet)*12+int(inches)
        cm=total_inches*2.54
        converted_heights.append(cm)
    else:
        cm = float(height[:-2])  # Remove the last two characters ("cm")
        converted_heights.append(cm)

# %%
df['Height']=converted_heights
df['Height']
# Out:
# 0        170.0
# 1        187.0
# 2        188.0
# 3        181.0
# 4        175.0
#          ...
# 18974    178.0
# 18975    175.0
# 18976    179.0
# 18977    175.0
# 18978    188.0
# Name: Height, Length: 18979, dtype: float64

# %%
# for weight in df['Weight']:
#     print(weight)

# %%
weight_to_kgs=[]

for weight in df['Weight']:
    if 'lbs' in weight:
        lbs = float(weight[:-3])
        weight_kg=lbs*0.4535
        weight_to_kgs.append(weight_kg)
    else:
        kg=float(weight[:-2])
        weight_to_kgs.append(kg)
# 0        72.0
# 1        83.0
# 2        87.0
# 3        70.0
# 4        68.0
#          ...
# 18974    66.0
# 18975    65.0
# 18976    74.0
# 18977    69.0
# 18978    75.0
# Name: Weight, Length: 18979, dtype: float64

# %%
df['Joined']
# Out:
# 0         Jul 1, 2004
# 1        Jul 10, 2018
# 2        Jul 16, 2014
# 3        Aug 30, 2015
# 4         Aug 3, 2017
#              ...
# 18974    Jul 13, 2018
# 18975     Aug 1, 2020
# 18976     Mar 8, 2019
# 18977    Sep 22, 2020
# 18978    Jul 29, 2019
# Name: Joined, Length: 18979, dtype: object

# %%
from datetime import datetime

df['Joined']=pd.to_datetime(df['Joined'], format="%b %d, %Y")
df['Joined']
# Out:
# 0       2004-07-01
# 1       2018-07-10
# 2       2014-07-16
# 3       2015-08-30
# 4       2017-08-03
#            ...
# 18974   2018-07-13
# 18975   2020-08-01
# 18976   2019-03-08
# 18977   2020-09-22
# 18978   2019-07-29
# Name: Joined, Length: 18979, dtype: datetime64[ns]

# %%
df['Year']=df['Joined'].dt.year
df['Month']=df['Joined'].dt.month
df['Day']=df['Joined'].dt.day

df.head()
# Out:
#        ID               Name                      LongName Nationality  Age  \
# 0  158023           L. Messi                  Lionel Messi   Argentina   33
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal   35
# 2  200389           J. Oblak                     Jan Oblak    Slovenia   27
# 3  192985       K. De Bruyne               Kevin De Bruyne     Belgium   29
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil   28
#
#    ↓OVA  POT                 Club     Contract   Positions  Height  Weight  \
# 0    93   93         FC Barcelona  2004 ~ 2021  RW, ST, CF   170.0    72.0
# 1    92   92             Juventus  2018 ~ 2022      ST, LW   187.0    83.0
# 2    91   93      Atlético Madrid  2014 ~ 2023          GK   188.0    87.0
# 3    91   91      Manchester City  2015 ~ 2023     CAM, CM   181.0    70.0
# 4    91   91  Paris Saint-Germain  2017 ~ 2022     LW, CAM   175.0    68.0
#
#   Preferred Foot  BOV Best Position     Joined    Value   Wage Release Clause  \
# 0           Left   93            RW 2004-07-01  €103.5M  €560K        €138.4M
# 1          Right   92            ST 2018-07-10     €63M  €220K         €75.9M
# 2          Right   91            GK 2014-07-16    €120M  €125K        €159.4M
# 3          Right   91           CAM 2015-08-30    €129M  €370K          €161M
# 4          Right   91            LW 2017-08-03    €132M  €270K        €166.5M
#
#    Attacking  Crossing  Finishing  Heading Accuracy  Short Passing  Volleys  \
# 0        429        85         95                70             91       88
# 1        437        84         95                90             82       86
# 2         95        13         11                15             43       13
# 3        407        94         82                55             94       82
# 4        408        85         87                62             87       87
#
#    Skill  Dribbling  Curve  FK Accuracy  Long Passing  Ball Control  Movement  \
# 0    470         96     93           94            91            96       451
# 1    414         88     81           76            77            92       431
# 2    109         12     13           14            40            30       307
# 3    441         88     85           83            93            92       398
# 4    448         95     88           89            81            95       453
#
#    Acceleration  Sprint Speed  Agility  Reactions  Balance  Power  Shot Power  \
# 0            91            80       91         94       95    389          86
# 1            87            91       87         95       71    444          94
# 2            43            60       67         88       49    268          59
# 3            77            76       78         91       76    408          91
# 4            94            89       96         91       83    357          80
#
#    Jumping  Stamina  Strength  Long Shots  Mentality  Aggression  \
# 0       68       72        69          94        347          44
# 1       95       84        78          93        353          63
# 2       78       41        78          12        140          34
# 3       63       89        74          91        408          76
# 4       62       81        50          84        356          51
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Defending  \
# 0             40           93      95         75         96         91
# 1             29           95      82         84         95         84
# 2             19           11      65         11         68         57
# 3             66           88      94         84         91        186
# 4             36           87      90         92         93         94
#
#    Marking  Standing Tackle  Sliding Tackle  Goalkeeping  GK Diving  \
# 0       32               35              24           54          6
# 1       28               32              24           58          7
# 2       27               12              18          437         87
# 3       68               65              53           56         15
# 4       35               30              29           59          9
#
#    GK Handling  GK Kicking  GK Positioning  GK Reflexes  Total Stats  \
# 0           11          15              14            8         2231
# 1           11          15              14           11         2221
# 2           92          78              90           90         1413
# 3           13           5              10           13         2304
# 4            9          15              15           11         2175
#
#    Base Stats  W/F  SM     A/W     D/W   IR  PAC  SHO  PAS  DRI  DEF  PHY  \
# 0         466  4 ★  4★  Medium     Low  5 ★   85   92   91   95   38   65
# 1         464  4 ★  5★    High     Low  5 ★   89   93   81   89   35   77
# 2         489  3 ★  1★  Medium  Medium  3 ★   87   92   78   90   52   90
# 3         485  5 ★  4★    High    High  4 ★   76   86   93   88   64   78
# 4         451  5 ★  5★    High  Medium  5 ★   91   85   86   94   36   59
#
#   Hits  Year  Month  Day
# 0  771  2004      7    1
# 1  562  2018      7   10
# 2  150  2014      7   16
# 3  207  2015      8   30
# 4  595  2017      8    3

# %%
# for i in df['Value']:
#     print(i)

# %%
converted_value=[]

for value in df['Value']:
    value=value.replace('M','000000')
    value=value.replace('K','000')
    value = value.replace('.', '')  # Remove .
    value=value.replace("€",'')
    converted_value.append(int(value))
    
df['Value']=converted_value
df['Value']
# Out:
# 0        1035000000
# 1          63000000
# 2         120000000
# 3         129000000
# 4         132000000
#             ...
# 18974        100000
# 18975        130000
# 18976        120000
# 18977        100000
# 18978        100000
# Name: Value, Length: 18979, dtype: int64

# %%
# for i in df['Wage']:
#     print(i)

# %%
converted_wage=[]

for wage in df['Wage']:
    wage=wage.replace('K','000')
    wage=wage.replace('€','')
    converted_wage.append(int(wage))
    
df['Wage']=converted_wage
df['Wage']
# print(converted_wage)
# Out:
# 0        560000
# 1        220000
# 2        125000
# 3        370000
# 4        270000
#           ...
# 18974      1000
# 18975       500
# 18976       500
# 18977      2000
# 18978      1000
# Name: Wage, Length: 18979, dtype: int64

# %%
# for i in df['Release Clause']:
#     print(i)

# %%
converted_clause=[]

for clause in df['Release Clause']:
    clause=clause.replace('€','')
    clause=clause.replace('.','')
    clause=clause.replace('M','000000')
    clause=clause.replace('K','000')
    converted_clause.append(int(clause))

df['Release Clause']=converted_clause
df['Release Clause']
# Out:
# 0        1384000000
# 1         759000000
# 2        1594000000
# 3         161000000
# 4        1665000000
#             ...
# 18974         70000
# 18975        165000
# 18976        131000
# 18977         88000
# 18978         79000
# Name: Release Clause, Length: 18979, dtype: int64

# %%
converted_hits=[]

for hit in df['Hits']:
    if pd.notnull(hit):  # Check if the value is not NaN
        if isinstance(hit, float):
            hit = str(hit).replace('K', '000').replace('.', '')
        else:
            hit = hit.replace('K', '000').replace('.', '')
        converted_hits.append(int(hit))
    
# Create a new Series object with converted_hits
hits_series = pd.Series(converted_hits)

# Assign the Series to the 'Hits' column of the DataFrame
df['Hits'] = hits_series

print(df['Hits'])
# Out:
# 0        771.0
# 1        562.0
# 2        150.0
# 3        207.0
# 4        595.0
#          ...
# 18974      NaN
# 18975      NaN
# 18976      NaN
# 18977      NaN
# 18978      NaN
# Name: Hits, Length: 18979, dtype: float64

# %%
df['Hits'].describe()
# Out:
# count    16384.000000
# mean        54.104065
# std        989.268825
# min          1.000000
# 25%          2.000000
# 50%          5.000000
# 75%         15.000000
# max      84000.000000
# Name: Hits, dtype: float64

# %%
import numpy as np

median_hits=np.nanmedian(df['Hits']) # Calculate the median ignoring NaN values

df['Hits'] = df['Hits'].fillna(median_hits) # Impute missing values with the median
df['Hits'].describe()
# Out:
# count    18979.000000
# mean        47.390063
# std        919.303602
# min          1.000000
# 25%          3.000000
# 50%          5.000000
# 75%         12.000000
# max      84000.000000
# Name: Hits, dtype: float64

# %%
#As Hits column has outliers and mean is effected by outliers, imputed null values with median

# %%
# percent_missing = (df.isnull().sum() * 100) / len(df)
# missing_value_df = pd.DataFrame({'column_name': df.columns,
#                                  'percent_missing': percent_missing})
# print(missing_value_df)

# pd.set_option('display.max_columns', None)

# %%
# #import matplotlib.pyplot as plt
# import seaborn as sns

# sns.boxplot(df['Hits'])

# %%
df['W/F']
# Out:
# 0        4 ★
# 1        4 ★
# 2        3 ★
# 3        5 ★
# 4        5 ★
#         ...
# 18974    2 ★
# 18975    2 ★
# 18976    2 ★
# 18977    3 ★
# 18978    3 ★
# Name: W/F, Length: 18979, dtype: object

# %%
converted_wf=[]

for wf in df['W/F']:
    wf=wf[:-2]  #to remove last 2 characters
    converted_wf.append(int(wf))
df['W/F']= converted_wf
df['W/F']
# Out:
# 0        4
# 1        4
# 2        3
# 3        5
# 4        5
#         ..
# 18974    2
# 18975    2
# 18976    2
# 18977    3
# 18978    3
# Name: W/F, Length: 18979, dtype: int64

# %%
df['SM']
# Out:
# 0        4★
# 1        5★
# 2        1★
# 3        4★
# 4        5★
#          ..
# 18974    2★
# 18975    2★
# 18976    2★
# 18977    2★
# 18978    2★
# Name: SM, Length: 18979, dtype: object

# %%
converted_sm=[]

for sm in df['SM']:
    sm=sm[:-1]
    converted_sm.append(int(sm))
    
df['SM']=converted_sm
df['SM']
# Out:
# 0        4
# 1        5
# 2        1
# 3        4
# 4        5
#         ..
# 18974    2
# 18975    2
# 18976    2
# 18977    2
# 18978    2
# Name: SM, Length: 18979, dtype: int64

# %%
df['IR']
# Out:
# 0        5 ★
# 1        5 ★
# 2        3 ★
# 3        4 ★
# 4        5 ★
#         ...
# 18974    1 ★
# 18975    1 ★
# 18976    1 ★
# 18977    1 ★
# 18978    1 ★
# Name: IR, Length: 18979, dtype: object

# %%
converted_ir=[]

for ir in df['IR']:
    ir=ir[:-2]
    converted_ir.append(int(ir))
    
df['IR']=converted_ir
df['IR']
# Out:
# 0        5
# 1        5
# 2        3
# 3        4
# 4        5
#         ..
# 18974    1
# 18975    1
# 18976    1
# 18977    1
# 18978    1
# Name: IR, Length: 18979, dtype: int64
